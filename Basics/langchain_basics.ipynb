# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
#setting up chatmodels
from langchain_openai import ChatOpenAI
gpt4o_chat = ChatOpenAI(model="gpt-4o", temperature=0, openai_api_key=api_key)
gpt35_chat = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0)

# %%
text = 'what are 5 vacation destinations for someone who likes to eat pasta'
gpt4o_chat.invoke(text)
# Out:
# AIMessage(content="If you're a pasta enthusiast, there are several destinations around the world where you can indulge in delicious pasta dishes. Here are five vacation spots that are perfect for pasta lovers:\n\n1. **Rome, Italy**: As the capital of Italy, Rome offers a rich culinary scene with a variety of pasta dishes. You can enjoy classics like Carbonara, Cacio e Pepe, and Amatriciana in traditional trattorias and modern eateries alike.\n\n2. **Bologna, Italy**: Known as the gastronomic capital of Italy, Bologna is famous for its rich and hearty pasta dishes. Don't miss trying Tagliatelle al Ragù (commonly known as Bolognese sauce) and Tortellini in Brodo.\n\n3. **Naples, Italy**: While Naples is renowned for its pizza, it also offers fantastic pasta dishes. Try Spaghetti alle Vongole (spaghetti with clams) or Pasta e Fagioli (pasta and beans) for a taste of Neapolitan cuisine.\n\n4. **Florence, Italy**: In the heart of Tuscany, Florence is a great place to enjoy pasta with a regional twist. Pappardelle al Cinghiale (pasta with wild boar sauce) and Ribollita (a hearty soup with bread and vegetables) are must-tries.\n\n5. **Sorrento, Italy**: Located on the Amalfi Coast, Sorrento offers stunning views and delicious pasta dishes. Enjoy fresh seafood pasta like Scialatielli ai Frutti di Mare or try Gnocchi alla Sorrentina, a local specialty with tomato sauce and mozzarella.\n\nThese destinations not only offer incredible pasta but also provide a rich cultural experience, beautiful scenery, and a chance to explore the local way of life.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 359, 'prompt_tokens': 20, 'total_tokens': 379, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_92f14e8683', 'id': 'chatcmpl-BKvUH8WS338VrsH9ESwI5P1L9KGHo', 'finish_reason': 'stop', 'logprobs': None}, id='run-e12011e2-92ed-41a3-a451-05235d3e3f19-0', usage_metadata={'input_tokens': 20, 'output_tokens': 359, 'total_tokens': 379, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
